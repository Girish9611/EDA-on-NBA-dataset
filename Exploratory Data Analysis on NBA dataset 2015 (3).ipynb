# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#scraping the web for data and storing it in a variable called df2015

# %%
url = 'https://www.basketball-reference.com/leagues/NBA_2015_per_game.html'
html = pd.read_html(url, header = 0)
df2015 = html[0]

# %%
df2015.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  ORB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  18.9  2.2   4.9  ...  .784  1.2
# 1  2   Jordan Adams  SG  20  MEM  30   0   8.3  1.2   2.9  ...  .609  0.3
# 2  3   Steven Adams   C  21  OKC  70  67  25.3  3.1   5.7  ...  .502  2.8
# 3  4    Jeff Adrien  PF  28  MIN  17   0  12.6  1.1   2.6  ...  .579  1.4
# 4  5  Arron Afflalo  SG  29  TOT  78  72  32.1  4.8  11.3  ...  .843  0.3
#
#    DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  3.3  4.4  1.0  0.4  0.3  0.9  2.2   5.9
# 1  0.6  0.9  0.5  0.5  0.2  0.5  0.8   3.1
# 2  4.6  7.5  0.9  0.5  1.2  1.4  3.2   7.7
# 3  3.2  4.5  0.9  0.2  0.5  0.5  1.8   3.5
# 4  2.8  3.2  1.7  0.5  0.1  1.5  2.1  13.3
#
# [5 rows x 30 columns]

# %%
#Checking the shape of the dataframe

# %%
df2015.shape
# Out:
# (651, 30)

# %%
#Checking for missing values

# %%
df2015.isnull().sum()
# Out:
# Rk         0
# Player     0
# Pos        0
# Age        0
# Tm         0
# G          0
# GS         0
# MP         0
# FG         0
# FGA        0
# FG%        2
# 3P         0
# 3PA        0
# 3P%       81
# 2P         0
# 2PA        0
# 2P%        4
# eFG%       2
# FT         0
# FTA        0
# FT%       25
# ORB        0
# DRB        0
# TRB        0
# AST        0
# STL        0
# BLK        0
# TOV        0
# PF         0
# PTS        0
# dtype: int64

# %%
#Filling the missing values with 0

# %%
df=df2015.fillna(0)
df.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  ORB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  18.9  2.2   4.9  ...  .784  1.2
# 1  2   Jordan Adams  SG  20  MEM  30   0   8.3  1.2   2.9  ...  .609  0.3
# 2  3   Steven Adams   C  21  OKC  70  67  25.3  3.1   5.7  ...  .502  2.8
# 3  4    Jeff Adrien  PF  28  MIN  17   0  12.6  1.1   2.6  ...  .579  1.4
# 4  5  Arron Afflalo  SG  29  TOT  78  72  32.1  4.8  11.3  ...  .843  0.3
#
#    DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  3.3  4.4  1.0  0.4  0.3  0.9  2.2   5.9
# 1  0.6  0.9  0.5  0.5  0.2  0.5  0.8   3.1
# 2  4.6  7.5  0.9  0.5  1.2  1.4  3.2   7.7
# 3  3.2  4.5  0.9  0.2  0.5  0.5  1.8   3.5
# 4  2.8  3.2  1.7  0.5  0.1  1.5  2.1  13.3
#
# [5 rows x 30 columns]

# %%
#Rechecking for missing values

# %%
df.isnull().sum()
# Out:
# Rk        0
# Player    0
# Pos       0
# Age       0
# Tm        0
# G         0
# GS        0
# MP        0
# FG        0
# FGA       0
# FG%       0
# 3P        0
# 3PA       0
# 3P%       0
# 2P        0
# 2PA       0
# 2P%       0
# eFG%      0
# FT        0
# FTA       0
# FT%       0
# ORB       0
# DRB       0
# TRB       0
# AST       0
# STL       0
# BLK       0
# TOV       0
# PF        0
# PTS       0
# dtype: int64

# %%
df.head()
# Out:
#           Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...   FT%  ORB  \
# 0     Quincy Acy  PF  24  NYK  68  22  18.9  2.2   4.9  .459  ...  .784  1.2
# 1   Jordan Adams  SG  20  MEM  30   0   8.3  1.2   2.9  .407  ...  .609  0.3
# 2   Steven Adams   C  21  OKC  70  67  25.3  3.1   5.7  .544  ...  .502  2.8
# 3    Jeff Adrien  PF  28  MIN  17   0  12.6  1.1   2.6  .432  ...  .579  1.4
# 4  Arron Afflalo  SG  29  TOT  78  72  32.1  4.8  11.3  .424  ...  .843  0.3
#
#    DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  3.3  4.4  1.0  0.4  0.3  0.9  2.2   5.9
# 1  0.6  0.9  0.5  0.5  0.2  0.5  0.8   3.1
# 2  4.6  7.5  0.9  0.5  1.2  1.4  3.2   7.7
# 3  3.2  4.5  0.9  0.2  0.5  0.5  1.8   3.5
# 4  2.8  3.2  1.7  0.5  0.1  1.5  2.1  13.3
#
# [5 rows x 29 columns]

# %%
#Writing to CSV file

# %%
df.to_csv('nba2015.csv', index=False)

# %%
#Importing CSV file

# %%
df=pd.read_csv('nba2015.csv')

# %%
df.head()
# Out:
#           Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...    FT%  \
# 0     Quincy Acy  PF   24  NYK  68  22  18.9  2.2   4.9  0.459  ...  0.784
# 1   Jordan Adams  SG   20  MEM  30   0   8.3  1.2   2.9  0.407  ...  0.609
# 2   Steven Adams   C   21  OKC  70  67  25.3  3.1   5.7  0.544  ...  0.502
# 3    Jeff Adrien  PF   28  MIN  17   0  12.6  1.1   2.6  0.432  ...  0.579
# 4  Arron Afflalo  SG   29  TOT  78  72  32.1  4.8  11.3  0.424  ...  0.843
#
#    ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  1.2  3.3  4.4  1.0  0.4  0.3  0.9  2.2   5.9
# 1  0.3  0.6  0.9  0.5  0.5  0.2  0.5  0.8   3.1
# 2  2.8  4.6  7.5  0.9  0.5  1.2  1.4  3.2   7.7
# 3  1.4  3.2  4.5  0.9  0.2  0.5  0.5  1.8   3.5
# 4  0.3  2.8  3.2  1.7  0.5  0.1  1.5  2.1  13.3
#
# [5 rows x 29 columns]

# %%
#setting display to show all the records in the dataframe

# %%
pd.set_option('display.max_rows', df.shape[0]+1)

# %%
df
# Out:
#                        Player    Pos  Age   Tm   G  GS    MP   FG   FGA  \
# 0                  Quincy Acy     PF   24  NYK  68  22  18.9  2.2   4.9
# 1                Jordan Adams     SG   20  MEM  30   0   8.3  1.2   2.9
# 2                Steven Adams      C   21  OKC  70  67  25.3  3.1   5.7
# 3                 Jeff Adrien     PF   28  MIN  17   0  12.6  1.1   2.6
# 4               Arron Afflalo     SG   29  TOT  78  72  32.1  4.8  11.3
# 5               Arron Afflalo     SG   29  DEN  53  53  33.0  5.3  12.4
# 6               Arron Afflalo     SG   29  POR  25  19  30.1  3.8   9.1
# 7               Alexis Ajinça      C   26  NOP  68   8  14.1  2.7   4.8
# 8              Furkan Aldemir     PF   23  PHI  41   9  13.2  1.0   1.9
# 9                Cole Aldrich      C   26  NYK  61  16  16.0  2.4   4.9
# 10          LaMarcus Aldridge     PF   29  POR  71  71  35.4  9.3  19.9
# 11                Lavoy Allen      C   25  IND  63   0  17.0  2.2   4.7
# ...

# %%
#setting display to only 10 rows

# %%
pd.set_option('display.max_rows', 10)

# %%
df
# Out:
#              Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...    FT%  \
# 0        Quincy Acy  PF   24  NYK  68  22  18.9  2.2   4.9  0.459  ...  0.784
# 1      Jordan Adams  SG   20  MEM  30   0   8.3  1.2   2.9  0.407  ...  0.609
# 2      Steven Adams   C   21  OKC  70  67  25.3  3.1   5.7  0.544  ...  0.502
# 3       Jeff Adrien  PF   28  MIN  17   0  12.6  1.1   2.6  0.432  ...  0.579
# 4     Arron Afflalo  SG   29  TOT  78  72  32.1  4.8  11.3  0.424  ...  0.843
# ..              ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...    ...
# 646  Thaddeus Young  PF   26  TOT  76  68  32.0  5.9  12.7  0.466  ...  0.655
# 647  Thaddeus Young  PF   26  MIN  48  48  33.4  6.0  13.4  0.451  ...  0.682
# 648  Thaddeus Young  PF   26  BRK  28  20  29.6  5.8  11.7  0.495  ...  0.606
# 649     Cody Zeller   C   22  CHO  62  45  24.0  2.8   6.0  0.461  ...  0.774
# 650    Tyler Zeller   C   25  BOS  82  59  21.1  4.1   7.5  0.549  ...  0.823
#
# ...

# %%
#Checking the datatypes of the elements of the dataframe

# %%
df.dtypes
# Out:
# Player     object
# Pos        object
# Age         int64
# Tm         object
# G           int64
#            ...
# STL       float64
# BLK       float64
# TOV       float64
# PF        float64
# PTS       float64
# Length: 29, dtype: object

# %%
#Checking which columns have nuemrical values

# %%
df.select_dtypes(include=['number'])
# Out:
#      Age   G  GS    MP   FG   FGA    FG%   3P  3PA    3P%  ...    FT%  ORB  \
# 0     24  68  22  18.9  2.2   4.9  0.459  0.3  0.9  0.300  ...  0.784  1.2
# 1     20  30   0   8.3  1.2   2.9  0.407  0.3  0.8  0.400  ...  0.609  0.3
# 2     21  70  67  25.3  3.1   5.7  0.544  0.0  0.0  0.000  ...  0.502  2.8
# 3     28  17   0  12.6  1.1   2.6  0.432  0.0  0.0  0.000  ...  0.579  1.4
# 4     29  78  72  32.1  4.8  11.3  0.424  1.5  4.3  0.354  ...  0.843  0.3
# ..   ...  ..  ..   ...  ...   ...    ...  ...  ...    ...  ...    ...  ...
# 646   26  76  68  32.0  5.9  12.7  0.466  0.5  1.5  0.330  ...  0.655  1.7
# 647   26  48  48  33.4  6.0  13.4  0.451  0.4  1.4  0.292  ...  0.682  1.6
# 648   26  28  20  29.6  5.8  11.7  0.495  0.7  1.8  0.380  ...  0.606  1.9
# 649   22  62  45  24.0  2.8   6.0  0.461  0.0  0.0  1.000  ...  0.774  1.6
# 650   25  82  59  21.1  4.1   7.5  0.549  0.0  0.0  0.000  ...  0.823  1.8
#
#      DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
#Checking which columns have objects

# %%
df.select_dtypes(include=['object'])
# Out:
#              Player Pos   Tm
# 0        Quincy Acy  PF  NYK
# 1      Jordan Adams  SG  MEM
# 2      Steven Adams   C  OKC
# 3       Jeff Adrien  PF  MIN
# 4     Arron Afflalo  SG  TOT
# ..              ...  ..  ...
# 646  Thaddeus Young  PF  TOT
# 647  Thaddeus Young  PF  MIN
# 648  Thaddeus Young  PF  BRK
# 649     Cody Zeller   C  CHO
# 650    Tyler Zeller   C  BOS
#
# [651 rows x 3 columns]

# %%
#QUESTIONS TO ANSWER USING EXPLORATORY DATA ANALYSIS

# %%
#Which player scored the most points per game?

# %%
df[df.PTS==df.PTS.max()]
# Out:
#                 Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  \
# 615  Russell Westbrook  PG   26  OKC  67  67  34.4  9.4  22.0  0.426  ...
#
#        FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 615  0.835  1.9  5.4  7.3  8.6  2.1  0.2  4.4  2.7  28.1
#
# [1 rows x 29 columns]

# %%
PlayerTeam=df[df.PTS==df.PTS.max()]

# %%
#What team did this player in?

# %%
PlayerTeam.Tm
# Out:
# 615    OKC
# Name: Tm, dtype: object

# %%
#Which position did this player play at?

# %%
PlayerTeam.Pos
# Out:
# 615    PG
# Name: Pos, dtype: object

# %%
#How many games did player play in the season?

# %%
PlayerTeam.G
# Out:
# 615    67
# Name: G, dtype: int64

# %%
#Players who scored more than 20 points per game

# %%
df[df['PTS']>20]
# Out:
#                 Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  \
# 10   LaMarcus Aldridge  PF   29  POR  71  71  35.4  9.3  19.9  0.466  ...
# 22     Carmelo Anthony  SF   30  NYK  40  40  35.7  9.0  20.2  0.444  ...
# 68          Chris Bosh   C   30  MIA  44  44  35.4  7.8  16.9  0.460  ...
# 79        Kobe Bryant*  SG   36  LAL  35  35  34.5  7.6  20.4  0.373  ...
# 125   DeMarcus Cousins   C   24  SAC  59  59  34.1  8.4  18.1  0.467  ...
# ..                 ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...
# 289       LeBron James  SF   30  CLE  69  69  36.1  9.0  18.5  0.488  ...
# 350     Damian Lillard  PG   24  POR  82  82  35.7  7.2  16.6  0.434  ...
# 581      Klay Thompson  SG   24  GSW  77  77  31.9  7.8  16.9  0.463  ...
# 601        Dwyane Wade  SG   33  MIA  62  62  31.8  8.2  17.5  0.470  ...
# 615  Russell Westbrook  PG   26  OKC  67  67  34.4  9.4  22.0  0.426  ...
#
#        FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
#Which player had highest 3 point field goals per game?

# %%
df[df['3P']==df['3P'].max()]
# Out:
#             Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...    FT%  \
# 135  Stephen Curry  PG   26  GSW  80  80  32.7  8.2  16.8  0.487  ...  0.914
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 135  0.7  3.6  4.3  7.7  2.0  0.2  3.1  2.0  23.8
#
# [1 rows x 29 columns]

# %%
#Which player has highest assists per game?

# %%
df[df['AST']==df['AST'].max()]
# Out:
#           Player Pos  Age   Tm   G  GS    MP   FG  FGA    FG%  ...    FT%  \
# 506  Rajon Rondo  PG   28  BOS  22  22  31.8  3.7  9.1  0.405  ...  0.333
#
#      ORB  DRB  TRB   AST  STL  BLK  TOV   PF  PTS
# 506  1.1  6.4  7.5  10.8  1.7  0.1  3.4  1.9  8.3
#
# [1 rows x 29 columns]

# %%
#Which player scored the highest in Los Angeles Lakers

# %%
LAL=df.groupby('Tm').get_group('LAL')
LAL
# Out:
#             Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...    FT%  \
# 58     Tarik Black   C   23  LAL  38  27  21.1  2.9   5.0  0.589  ...  0.562
# 62     Vander Blue  SG   22  LAL   2   1  37.0  4.5  15.0  0.300  ...  0.400
# 67   Carlos Boozer  PF   33  LAL  71  26  23.8  5.2  10.5  0.499  ...  0.627
# 75    Jabari Brown  SG   22  LAL  19   5  29.9  3.7   8.9  0.412  ...  0.753
# 79    Kobe Bryant*  SG   36  LAL  35  35  34.5  7.6  20.4  0.373  ...  0.813
# ..             ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...    ...
# 351     Jeremy Lin  PG   26  LAL  74  30  25.8  3.7   8.8  0.424  ...  0.795
# 473   Ronnie Price  PG   31  LAL  43  20  22.8  1.8   5.2  0.345  ...  0.800
# 482  Julius Randle  PF   20  LAL   1   0  14.0  1.0   3.0  0.333  ...  0.000
# 513   Robert Sacre   C   25  LAL  67  18  16.9  1.9   4.6  0.412  ...  0.671
# 645     Nick Young  SG   29  LAL  42   0  23.8  4.1  11.3  0.366  ...  0.892
#
# ...

# %%
LAL[LAL['PTS']==LAL['PTS'].max()]
# Out:
#           Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...    FT%  \
# 79  Kobe Bryant*  SG   36  LAL  35  35  34.5  7.6  20.4  0.373  ...  0.813
#
#     ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 79  0.7  4.9  5.7  5.6  1.3  0.2  3.7  1.9  22.3
#
# [1 rows x 29 columns]

# %%
#Of the 5 positions, which position has scored the most?

# %%
df.groupby('Pos').PTS.describe()
# Out:
#        count       mean        std  min    25%    50%     75%   max
# Pos
# C      101.0   7.428713   5.014905  0.0  3.700   6.60  10.200  24.1
# PF     142.0   7.079577   4.954424  0.0  3.025   6.30  10.125  24.4
# PF-SF    1.0   7.100000        NaN  7.1  7.100   7.10   7.100   7.1
# PG     141.0   8.695035   5.609117  0.0  4.300   7.40  12.600  28.1
# PG-SG    2.0  12.000000   7.071068  7.0  9.500  12.00  14.500  17.0
# ...      ...        ...        ...  ...    ...    ...     ...   ...
# SF-PF    1.0   1.800000        NaN  1.8  1.800   1.80   1.800   1.8
# SF-SG    1.0   7.200000        NaN  7.2  7.200   7.20   7.200   7.2
# SG     143.0   8.329371   5.510193  0.0  3.600   7.40  11.950  27.4
# SG-PG    2.0   8.750000  10.677312  1.2  4.975   8.75  12.525  16.3
# SG-SF    1.0   2.100000        NaN  2.1  2.100   2.10   2.100   2.1
#
# [11 rows x 8 columns]

# %%
#Since there are hybrid positions, i have introduced a list positions with the main positions and make a subset dataframe of those positions

# %%
positions = ['C','PF','SF','PG','SG']
POS = df[ df['Pos'].isin(positions)  ]
POS
# Out:
#              Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...    FT%  \
# 0        Quincy Acy  PF   24  NYK  68  22  18.9  2.2   4.9  0.459  ...  0.784
# 1      Jordan Adams  SG   20  MEM  30   0   8.3  1.2   2.9  0.407  ...  0.609
# 2      Steven Adams   C   21  OKC  70  67  25.3  3.1   5.7  0.544  ...  0.502
# 3       Jeff Adrien  PF   28  MIN  17   0  12.6  1.1   2.6  0.432  ...  0.579
# 4     Arron Afflalo  SG   29  TOT  78  72  32.1  4.8  11.3  0.424  ...  0.843
# ..              ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...    ...
# 646  Thaddeus Young  PF   26  TOT  76  68  32.0  5.9  12.7  0.466  ...  0.655
# 647  Thaddeus Young  PF   26  MIN  48  48  33.4  6.0  13.4  0.451  ...  0.682
# 648  Thaddeus Young  PF   26  BRK  28  20  29.6  5.8  11.7  0.495  ...  0.606
# 649     Cody Zeller   C   22  CHO  62  45  24.0  2.8   6.0  0.461  ...  0.774
# 650    Tyler Zeller   C   25  BOS  82  59  21.1  4.1   7.5  0.549  ...  0.823
#
# ...

# %%
POS.groupby('Pos').PTS.describe()
# Out:
#      count      mean       std  min    25%   50%     75%   max
# Pos
# C    101.0  7.428713  5.014905  0.0  3.700  6.60  10.200  24.1
# PF   142.0  7.079577  4.954424  0.0  3.025  6.30  10.125  24.4
# PG   141.0  8.695035  5.609117  0.0  4.300  7.40  12.600  28.1
# SF   116.0  7.274138  5.267144  0.4  3.700  5.85   9.425  25.4
# SG   143.0  8.329371  5.510193  0.0  3.600  7.40  11.950  27.4

# %%
#Answering the same question using histograms by creating a subset dataframe and plotting a histogram

# %%
PTS=df[['Pos','PTS']]

# %%
positions = ['C','PF','SF','PG','SG']
PTS = PTS[ PTS['Pos'].isin(positions)]

PTS
# Out:
#     Pos   PTS
# 0    PF   5.9
# 1    SG   3.1
# 2     C   7.7
# 3    PF   3.5
# 4    SG  13.3
# ..   ..   ...
# 646  PF  14.1
# 647  PF  14.3
# 648  PF  13.8
# 649   C   7.6
# 650   C  10.2
#
# [643 rows x 2 columns]

# %%
PTS['PTS'].hist(by=PTS['Pos'],figsize=(16,2),layout=(1,5))
# Out:
# array([<AxesSubplot:title={'center':'C'}>,
#        <AxesSubplot:title={'center':'PF'}>,
#        <AxesSubplot:title={'center':'PG'}>,
#        <AxesSubplot:title={'center':'SF'}>,
#        <AxesSubplot:title={'center':'SG'}>], dtype=object)

# %%
#Constructing a correlation matrix

# %%
corr=df.corr()
corr
# Out:
#           Age         G        GS        MP        FG       FGA       FG%  \
# Age  1.000000  0.126081  0.029215  0.083910  0.056601  0.042123  0.076122
# G    0.126081  1.000000  0.635509  0.614513  0.525480  0.482908  0.328652
# GS   0.029215  0.635509  1.000000  0.778166  0.737337  0.696204  0.255850
# MP   0.083910  0.614513  0.778166  1.000000  0.897466  0.901404  0.250283
# FG   0.056601  0.525480  0.737337  0.897466  1.000000  0.974527  0.315602
# ..        ...       ...       ...       ...       ...       ...       ...
# STL -0.005944  0.390675  0.550555  0.737470  0.657233  0.688928  0.102409
# BLK -0.015053  0.331396  0.411740  0.351295  0.364617  0.253431  0.407620
# TOV -0.005866  0.373425  0.584644  0.780713  0.785813  0.817072  0.146925
# PF   0.043409  0.523624  0.587599  0.724308  0.621027  0.589105  0.317137
# PTS  0.051347  0.514779  0.717790  0.893393  0.986787  0.977955  0.270405
#
#            3P       3PA       3P%  ...       FT%       ORB       DRB  \
# ...

# %%
#heatmap of correlation matrix

# %%
fig,ax = plt.subplots(figsize=(7,5))
sns.heatmap(corr,square=True)
# Out:
# <AxesSubplot:>

# %%
#scatterplot for specific column names

# %%
selections = ['Age', 'G', 'STL', 'BLK', 'AST', 'PTS']
dfscatter = df[selections]
dfscatter
# Out:
#      Age   G  STL  BLK  AST   PTS
# 0     24  68  0.4  0.3  1.0   5.9
# 1     20  30  0.5  0.2  0.5   3.1
# 2     21  70  0.5  1.2  0.9   7.7
# 3     28  17  0.2  0.5  0.9   3.5
# 4     29  78  0.5  0.1  1.7  13.3
# ..   ...  ..  ...  ...  ...   ...
# 646   26  76  1.6  0.3  2.3  14.1
# 647   26  48  1.8  0.4  2.8  14.3
# 648   26  28  1.4  0.3  1.4  13.8
# 649   22  62  0.5  0.8  1.6   7.6
# 650   25  82  0.2  0.6  1.4  10.2
#
# [651 rows x 6 columns]

# %%
g=sns.PairGrid(dfscatter)
g.map(plt.scatter);
